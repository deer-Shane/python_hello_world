# %%
jinx_info = {
	"hair":"blue",
	"weapon":"gun",
	"eye":"purple",
	}
print(jinx_info)
# Out:
# {'hair': 'blue', 'weapon': 'gun', 'eye': 'purple'}

# %%
for info in jinx_info:
    print(info,":",jinx_info[info])
# Out:
# hair : blue
# weapon : gun
# eye : purple
